# %%
import pandas as pd
data_xls = pd.read_excel('nome do arquivo', 'Sheet1', dtype=str, index_col=None)
data_xls.to_csv('nome do arquivo de saida.csv', encoding='utf-8', index=False)

# %%
df = pd.read_csv('nome do arquivo de saida.csv')

# %%
df
# Out:
#                                             Razao Social  \
# 0                               DISKTRANS COMERCIAL LTDA
# 1                    DISLAB COMERCIAL FARMACEUTICA LTDA.
# 2                                 DISMASA LOGISTICA LTDA
# 3      DISMAX DISTRIBUICAO E REPRESENTACAO DE PRODUTO...
# 4      DISMED - DISTRIBUIDORA DE MEDICAMENTOS OLIMPIA...
# ...                                                  ...
# 9997                  ZURICH BRASIL COMPANHIA DE SEGUROS
# 9998   ZURICH IND.E COM.DE DERIVADOS TERMO PLASTICOS ...
# 9999   ZURICH SANTANDER BRASIL SEGUROS E PREVIDENCIA ...
# 10000  ZUZA PRESTADORA DE SERVICOS EM BENEFICIAMENTO ...
# 10001  ZZK INDUSTRIA E COMERCIO DE PECAS AUTOMOTIVAS ...
#
#                      Nome Fantasia                       Logradouro numero  \
# 0                              NaN         ANTONIO OVIDIO RODRIGUES   1389
# 1                              NaN                       ANHANGUERA     SN
# ...
